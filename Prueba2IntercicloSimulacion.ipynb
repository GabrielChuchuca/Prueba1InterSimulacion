# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielChuchuca/Prueba1InterSimulacion/blob/main/Prueba2IntercicloSimulacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install simpy

# %%
import simpy
import random

# %% [markdown]
# Solo se va a tener en cuenta uno de los planteles educativos(Escuela, colegio, universidad dentro del Azuay).

# %%
N_ESTUDIANTES = 473
N_DOCENTES = 29

# %% [markdown]
# Se tiene un promedio que el 90% de los docentes han sido vacunados y pueden realizar el proceso de ingreso en cada uno de los cursos.

# %%
DOCENTES_VACUNADOS = int((N_DOCENTES*90)/100)
print("El numero de docentes vacunados: {}".format(DOCENTES_VACUNADOS))
# Out:
# El numero de docentes vacunados: 26

# %% [markdown]
# Dentro del procesos se tiene que alrededor del 5% - 10% de los estudiantes no podrán asistir debido a no presentar la vacuna/enfermedades adyacentes.

# %%
n_aleatorio = random.randint(5, 10)
ESTUDIANTES_NO_VACUNADOS = int((N_ESTUDIANTES*n_aleatorio)/100)
ESTUDIANTES_VACUNADOS = N_ESTUDIANTES - ESTUDIANTES_NO_VACUNADOS
print("El numero de estudiantes vacunados: {}".format(ESTUDIANTES_VACUNADOS))
AULAS = 15
# Out:
# El numero de estudiantes vacunados: 436

# %%
class Institucion():
  """cada clase dura 41 minutos y son 8 clases al dia y 30 minutos de receso que dan 6 horas dirais"""
  def __init__(self, env, num_aulas, nombre_institucion):
    self.env = env
    self.aulas = simpy.Resource(env, num_aulas)

# %%
es_x_aula = round(N_ESTUDIANTES / AULAS)
es_x_aula
# Out:
# 29

# %%
def llenado(env, estudiante, colegio):
  with colegio.aulas.request() as aula:
    if estudiante < es_x_aula - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 1'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*2) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 2'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*3) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 3'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*4) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 4'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*5) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 5'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*6) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 6'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*7) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 7'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*8) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 8'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*9) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 9'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*10) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 10'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*11) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 11'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*12) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 12'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*13) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 13'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*14) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 14'.format(estudiante, env.now))
      yield aula
    elif estudiante < (es_x_aula*15) - 1:
      print('Llega el estudiante {} a la institucion al tiempo {} al aula 15'.format(estudiante, env.now))
      yield aula

# %%
def llenado_doc(env, docente, colegio, au):
   #d = list(range(docente))
   #a = random.sample(d, 15)
   with colegio.aulas.request() as aula:   
    if docente>0:
      print("El docente {} llega en el tiempo {} al aula {}".format(docente, env.now, au + 1)) if au < 15 else None
      yield env.timeout(0.001)
      print("El docente {} inicia la clase en el tiempo {} al aula {}".format(docente, env.now, au + 1)) if au < 15 else None
      yield aula

# %%
#def pre_recreo(env, docente, colegio):

# %%
def simulacion(env, num_aulas, estudiantes, docentes):
  institucion = Institucion(env, num_aulas, "FRANCISCO TAMARIZ")
  print("***LLEGADA DE LOS ALUMNOS A LAS AULAS***")
  for i in range(estudiantes):
        env.process(llenado(
            env,(i+1),institucion))
  
  yield env.timeout(0.002)
  print("***LLEGADA DE LOS DEOCENTES A LAS AULAS***")
  d = list(range(docentes))
  a = random.sample(d, 15)
  for j in range(num_aulas):
    env.process(llenado_doc(env, a[j]+ 1, institucion, j))
  yield env.timeout(0)

# %%
if __name__ == "__main__":
  print("Punto de vacunacion en Cuenca")
  # Creamos el entorno de simulacion
  env=simpy.Environment()
  print("# de Estudinates vacunados o con certificado => ", ESTUDIANTES_VACUNADOS)
  env.process(simulacion(env, AULAS, ESTUDIANTES_VACUNADOS, DOCENTES_VACUNADOS))
  # Ejecutamos el proceso durante el tiempo de simulacion
  env.run(until = 1000)
# Out:
# Punto de vacunacion en Cuenca
# # de Estudinates vacunados o con certificado =>  436
# ***LLEGADA DE LOS ALUMNOS A LAS AULAS***
# Llega el estudiante 1 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 2 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 3 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 4 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 5 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 6 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 7 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 8 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 9 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 10 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 11 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 12 a la institucion al tiempo 0 al aula 1
# Llega el estudiante 13 a la institucion al tiempo 0 al aula 1
# ...

# %%
class Car(object):
  def __init__(self, env):
    self.env = env
    # Start the run process everytime an instance is created.
    self.action = env.process(self.run())

  def run(self):
    a = 0
    while a <4:
      print('Start parking and charging at %d' % self.env.now)
      charge_duration = 5
      # We yield the process that process() returns
      # to wait for it to finish
      yield self.env.process(self.charge(charge_duration))

      # The charge process has finished and
      # we can start driving again.
      print('Start driving at %d' % self.env.now)
      trip_duration = 2
      yield self.env.timeout(trip_duration)
      a = a + 1

  def charge(self, duration):
    yield self.env.timeout(duration)

# %%
if __name__ == "__main__":
    env = simpy.Environment()
    car = Car(env)
    env.run(until=60)
# Out:
# Start parking and charging at 0
# Start driving at 5
# Start parking and charging at 7
# Start driving at 12
# Start parking and charging at 14
# Start driving at 19
# Start parking and charging at 21
# Start driving at 26
